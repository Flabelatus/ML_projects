# %% [markdown]
# ## Notebook imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import log

# For the 3d plot
from mpl_toolkits.mplot3d.axes3d import Axes3D
# Color map
from matplotlib import cm

from sympy import symbols, diff

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# # 1 - A simple cost function
#
# $f(x) = x^2 + x + 1$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
print(f(5))
# Out:
# 31

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
#Plot

# plt.xlim(-3, 3)
plt.xlabel("X", fontsize=16)
plt.ylabel("f(x)", fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
# The slope of the curve at a given point
#
# ### Power Rule in Derivatives
#
# $df(x^n) = n.x^n-1 $

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot  function and derivative side by side

plt.figure(figsize=[10, 5])

# First chart: Cost function
plt.subplot(1, 2, 1)

plt.title("Cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("f(x)", fontsize=16)
plt.plot(x_1, f(x_1))

# Second chart: Derivative
plt.subplot(1, 2, 2)
plt.plot(x_1, df(x_1))
plt.grid()
plt.title("Slope of the cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("df(x)", fontsize=16)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Gradient Descent
new_x = 3
previous_x = 0
precision = 0.00000001

step_multiplier = 0.1

x_list = [new_x]
slope_list = [df(new_x)]

count = 0
while True:
    # new_x as a starting point at a random guess 
    previous_x = new_x
    
    # Slope of the graph
    gradient  = df(previous_x)
    
    # Update new_x value
    new_x = previous_x - step_multiplier * gradient
    step_size = abs(new_x - previous_x)
    
    count += 1
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size < precision:
        break

print(f"Iterated {count} times")

print("Local minimum occurs at: ", new_x)
print(f'Slope or df(x) value at this point is: {df(new_x)}')
print(f'f(x) value or cost at this point is: {f(new_x)}')
# Out:
# Iterated 82 times
# Local minimum occurs at:  -0.49999996042262573
# Slope or df(x) value at this point is: 7.915474853348314e-08
# f(x) value or cost at this point is: 0.7500000000000016

# %%
# Superimpose the gradient descent calculations
plt.figure(figsize=[10, 5])

# First chart: Cost function
plt.subplot(1, 2, 1)

plt.title("Cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("f(x)", fontsize=16)
plt.plot(x_1, f(x_1))

# The list to become a Numpy array and then use it in the f(x) function
values = np.array(x_list)
plt.scatter(x_list, f(values), color="red", s=100, alpha=0.4)

# Second chart: Derivative
plt.subplot(1, 2, 2)
plt.plot(x_1, df(x_1))
plt.grid()
plt.title("Slope of the cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("df(x)", fontsize=16)

plt.scatter(x_list, slope_list, color="red", s=100, alpha=0.4)

plt.show()

# %% [markdown]
# # 2 - Multiple Minima vs Initial Guess
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

# The g(x) function
def g(x):
    return (x**4) - (4 * (x**2)) + 5


def dg(x):
    return (4 * (x**3)) - (8 * x)

# %%
# Plot  function and derivative side by side

plt.figure(figsize=[10, 5])

# First chart: Cost function
plt.subplot(1, 2, 1)

plt.title("Cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("g(x)", fontsize=16)
plt.plot(x_2, g(x_2))

# Second chart: Derivative
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2))
plt.grid()
plt.title("Slope of the cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("dg(x)", fontsize=16)

plt.show()

# %% [markdown]
# ## Gradient Descent as a Python Function

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

# The g(x) function
def g(x):
    return x**4 - 4 * x**2+ 5


def dg(x):
    return 4 * x**3 - 8 * x


def gradient_descent(derivative_func, initial_guess, multiplier,
                     precision, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        
        step_size = abs(new_x  - previous_x)       
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        
        if step_size < precision:
            break
        
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 2, 0.02, 0.0001)

# %%
print(local_min)
print(len(list_x))
# Out:
# 1.4143888461883538
# 20

# %%
# Calling gradient descent function
# Plot  function and derivative side by side

plt.figure(figsize=[10, 5])

# First chart: Cost function
plt.subplot(1, 2, 1)

plt.title("Cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("g(x)", fontsize=16)

plt.plot(x_2, g(x_2), color='blue', alpha=0.8, linewidth=3)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# Second chart: Derivative
plt.subplot(1, 2, 2)

plt.plot(x_2, dg(x_2), color="skyblue", linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=60, alpha=0.5)

plt.grid()
plt.title("Slope of the cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("dg(x)", fontsize=16)

plt.show()

# %% [markdown]
# # 3 - Divergence, Overflow
# ## $$h(x) = x^5 + 2x^4 + 2$$

# %%
x_3 = np.linspace(start=-2.5, stop=2.5, num=1000)


def h(x):
    return x**5 - 2*x**4 + 2


def dh(x):
    return 5*x**4 - 8*x**3

# %%
local_min, list_x, deriv_list = gradient_descent(dh, -0.2, 0.02, 0.001, max_iter=70)

# Calling gradient descent function
# Plot  function and derivative side by side

plt.figure(figsize=[10, 5])

# First chart: Cost function
plt.subplot(1, 2, 1)

plt.title("Cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("h(x)", fontsize=16)

plt.xlim(-1, 2)
plt.ylim(-4, 5)

plt.plot(x_3, h(x_3), color='blue', alpha=0.8, linewidth=3)
plt.scatter(list_x, h(np.array(list_x)), color='red', s=100, alpha=0.6)

# Second chart: Derivative
plt.subplot(1, 2, 2)

plt.plot(x_3, dh(x_3), color="skyblue", linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=60, alpha=0.5)

plt.xlim(-1, 2)
plt.ylim(-4, 5)

plt.grid()
plt.title("Slope of the cost function", fontsize=17)
plt.xlabel("X", fontsize=16)
plt.ylabel("dh(x)", fontsize=16)

plt.show()

print('local min occurs at: ', local_min)
print('Cost at this minimum is: ', h(local_min))
print('Number of steps is: ', len(list_x))
# Out:
# local min occurs at:  -2071072.4470816324
# Cost at this minimum is:  -3.810455326061589e+31
# Number of steps is:  71

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
n = 100

low_gamma = gradient_descent(derivative_func=dg,
                                                 initial_guess=3,
                                                 multiplier=0.0005,
                                                 precision=0.0001,
                                                 max_iter=n
                                                )

mid_gamma = gradient_descent(derivative_func=dg,
                                                 initial_guess=3,
                                                 multiplier=0.001,
                                                 precision=0.0001,
                                                 max_iter=n
                                                )

high_gamma = gradient_descent(derivative_func=dg,
                                                 initial_guess=3,
                                                 multiplier=0.002,
                                                 precision=0.0001,
                                                 max_iter=n
                                                )

# Experiment
insane_gamma = gradient_descent(derivative_func=dg,
                                                 initial_guess=1.9,
                                                 multiplier=0.25,
                                                 precision=0.0001,
                                                 max_iter=n
                                                )

# Plot  function and derivative side by side

plt.figure(figsize=[20, 10])

plt.xlim(0, n)
plt.ylim(0, 50)

# First chart: Cost function

plt.title("Effect of the learning rate", fontsize=17)
plt.xlabel("Nr of iterations", fontsize=16)
plt.ylabel("Cost", fontsize=16)

# Values of our chart
# 1) Y Axis Data: conver the lists into numpy arrays
low_values = np.array(low_gamma[1])
mid_values = np.array(mid_gamma[1])
high_values = np.array(high_gamma[1])
experimental_values = np.array(insane_gamma[1])

# 2) X Axis Data: a list from 0 to n+1
iteration_list = list(range(0, n + 1))

# Plotting low learning rate
plt.plot(iteration_list, g(low_values), color='lightgreen', alpha=0.8, linewidth=3)
plt.scatter(iteration_list, g(low_values), color='lightgreen', s=80)

# Plotting mid learning rate
plt.plot(iteration_list, g(mid_values), color='deepskyblue', alpha=0.8, linewidth=3)
plt.scatter(iteration_list, g(mid_values), color='deepskyblue', s=80)

# Plotting high learning rate
plt.plot(iteration_list, g(high_values), color='hotpink', alpha=0.8, linewidth=3)
plt.scatter(iteration_list, g(high_values), color='hotpink', s=80)

# Plotting experimental learning rate
plt.plot(iteration_list, g(experimental_values), color='red', alpha=0.8, linewidth=3)
plt.scatter(iteration_list, g(experimental_values), color='red', s=80)

plt.show()

print("Number of steps: ", len(list_x))
# Out:
# Number of steps:  71

# %% [markdown]
# # 4 - Data visualization with 3D Charts
# ## Minimize $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 -y^2}$

# %%
def f(x, y):
    r = 3 ** (-x**2 - y**2)
    return 1 / (r + 1)

# %%
# Make data for x and y
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

# Vector shape
print("Shape of X array", x_4.shape)

# The x and y data has to be 2D array
x_4, y_4 = np.meshgrid(x_4, y_4)
print("Shape of X array after the meshgrid", x_4.shape)
# Out:
# Shape of X array (200,)
# Shape of X array after the meshgrid (200, 200)

# %%
# Generating 3D plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(projection='3d')

# Add labels to the axes
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)


ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.inferno, alpha=0.5)
plt.show()

# %% [markdown]
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = \frac {2x \ln(3) \cdot 3^{-x^2 - y^2}}{\left( 3^{-x^2 - y^2} + 1 \right)^2}$$
#
# ## $$\frac{\partial f}{\partial y} = \frac {2y \ln(3) \cdot 3^{-x^2 - y^2}}{\left( 3^{-x^2 - y^2} + 1 \right)^2}$$

# %%
def fpx(x, y):
    """Partial derivative function in respect to x"""
    r = 3 ** (-x ** 2 - y ** 2)
    partial_derivative = 2 * x * log(3) * r / (r + 1) ** 2
    return partial_derivative

def fpy(x, y):
    """Partial derivative function in respect to y"""
    r = 3 ** (-x ** 2 - y ** 2)
    partial_derivative = 2 * y * log(3) * r / (r + 1) ** 2
    return partial_derivative


a, b = symbols('x, y')
print("Our cost function f(x, y) is: ", f(a, b), "\n")

# Differentiating out function in respect to a using diff method from sympy
# To get the partial derivative function
df = diff(f(a, b), a)

print("Our partial derivative wrt x is: ", df, "\n")

# Evalf for evaluating function
custom_value = f(a, b).evalf(subs={a:1.8, b:1.0})
print("Value of f(x, y) at x=1.8, y=1.0 is: ", cost_at_a_point, "\n")

custom_slope = df.evalf(subs={a:1.8, b:1.0})
print("Value of partial derivative df(x, y) in \n"
      "respect to x at x=1.8, y=1.0 is: ", custom_slope)
# Out:
# Our cost function f(x, y) is:  1/(3**(-x**2 - y**2) + 1)
#
# Our partial derivative wrt x is:  2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5268/2294865891.py in <module>
#      23 # Evalf for evaluating function
#      24 custom_value = f(a, b).evalf(subs={a:1.8, b:1.0})
# ---> 25 print("Value of f(x, y) at x=1.8, y=1.0 is: ", cost_at_a_point, "\n")
#      26
#      27 custom_slope = df.evalf(subs={a:1.8, b:1.0})
#
# NameError: name 'cost_at_a_point' is not defined

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # Initial guess

# subs = {a:params[0], b:params[1]}

for n in range(max_iter):
#     gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
#     gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    
    # SymPy functions are slower to caclulate in terms of performance
    # Replacing the sympy diff functions with the Python functions defined 
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print("Values in graident array", gradients)
print("Minimum occurs at x value of: ", params[0])
print("Minimum occurs at y value of: ", params[1])
print("The cost is: ", f(params[0], params[1]))

# %%
fpx(1.8, 1.0)

# %% [markdown]
# ## Graphing 3D Gradient Descent & Adv Numpy Arrays

# %%
# Setup
multiplier = 0.1
max_iter = 100
params = np.array([1.8, 1.0]) # Initial guess

# Reshape the array into (1, 2) to store x values in first dimension and y
# in the second dimension
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):

    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
#     value_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)

# Results
print("Values in graident array", gradients)
print("Minimum occurs at x value of: ", params[0])
print("Minimum occurs at y value of: ", params[1])
print("The cost is: ", f(params[0], params[1]))
# Out:
# (1, 2)
# Values in graident array [0.13086082 0.07270045]
# Minimum occurs at x value of:  0.22554260634177148
# Minimum occurs at y value of:  0.12530144796765078
# The cost is:  0.518275488025232

# %%
# Numpy arrays 

# 1 row and 2 columns array
kirk = np.array([['Captain', 'Guitar']])
print(kirk.shape)

# 2 row and 2 columns array
hs_band = np.array([["Black Thought", "MC"], ["Questlove", "Drums"]])
print(hs_band.shape)

print('hs_band[0]', hs_band[0])
print('hs_band[1][0]', hs_band[1][0])

the_roots = np.append(arr=hs_band, values=kirk, axis=0)
print(the_roots)

print("Printing nicknames ... ", the_roots[:, 0])

# Played with Numpy shapes,
# in the 2D shapes, what you would see as first number represents the row
# And the second value represents the column

# Played with append method for np arrays. You can add values to existing
# arrays as long as they match the shape. For example, an array of shape (1, 2) 
# can be appended to the array with shape of (2, 2).
# Out:
# (1, 2)
# (2, 2)
# hs_band[0] ['Black Thought' 'MC']
# hs_band[1][0] Questlove
# [['Black Thought' 'MC']
#  ['Questlove' 'Drums']
#  ['Captain' 'Guitar']]
# Printing nicknames ...  ['Black Thought' 'Questlove' 'Captain']

# %%
# Generating 3D plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(projection='3d')

# Add labels to the axes
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.inferno, alpha=0.5)

ax.scatter(values_array[:, 0], values_array[:, 1], 
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')
plt.show()

# %% [markdown]
# # Example 5 - Working with Data & Real Cost Function
# ## Mean Squared Error: a const function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h \theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h \theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print("Array x_5 shape", x_5.shape)
print("Array y_5 shape", y_5.shape)
# Out:
# Array x_5 shape (7, 1)
# Array y_5 shape (7, 1)

# %%
# Quick linear regression
regr = LinearRegression()
regr.fit(x_5, y_5)
print("Theta 0: ", regr.intercept_[0])
print("Theta 1: ", regr.coef_[0][0])
# Out:
# Theta 0:  0.8475351486029536
# Theta 1:  1.2227264637835915

# %%
plt.scatter(x_5, y_5, s=50)
#  plot prediction according to x_5
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.8475351486029536 + 1.2227264637835915 * x_5
print('Estimated values y_hat are:\n', y_hat)
print('In comparision the actual y values:\n', y_5)
# Out:
# Estimated values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparision the actual y values:
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
def mse(y, y_hat):
    mse_calc = 1/y.size *  sum((y - y_hat) ** 2)
    return mse_calc

# %%
mse(y_5, y_hat)
# Out:
# array([0.94796558])
